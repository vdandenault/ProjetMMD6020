# %%
import papermill as pm
from logger import logger

# %%
for num, index in enumerate([1, 5, 10], start=1):
    logger.info('Running notebook for: {}'.format(index))
    pm.execute_notebook(input_path='notebook_vd.ipynb',parameters={'epoch': index, 'experiment': num},
        output_path='./notebooks/notebook_vd_epoch_{}.ipynb'.format(index))
# Out:
# [08/Dec/2021 08:03:15] INFO - Running notebook for: 1
# [08/Dec/2021 08:03:15] INFO - Input Notebook:  notebook_vd.ipynb
# [08/Dec/2021 08:03:15] INFO - Output Notebook: ./notebooks/notebook_vd_epoch_1.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# [08/Dec/2021 08:03:17] INFO - Executing notebook with kernel: python3
# 2021-12-08 08:09:55.601222: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-08 08:10:12.033424: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# [08/Dec/2021 08:13:10] WARNING - Autosave too slow: 9.48 sec, over 25% limit. Backing off to 60 sec
# ...
